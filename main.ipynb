# %%
total = 3
unidad = "dias"
for i in range(total):
  print("Han pasado " + str(i), unidad)
# Out:
# Han pasado 0 dias
# Han pasado 1 dias
# Han pasado 2 dias

# %%
total = 3
unidad = "dias"
for i in range(total):
  print("Han pasado " + str(i), unidad)
total = 4
unidad = "meses"
for i in range(total):
  print("Han pasado " + str(i), unidad)
total = 10
unidad = "meses"
for i in range(total):
  print("Han pasado " + str(i), unidad)
# Out:
# Han pasado 0 dias
# Han pasado 1 dias
# Han pasado 2 dias
# Han pasado 0 meses
# Han pasado 1 meses
# Han pasado 2 meses
# Han pasado 3 meses
# Han pasado 0 meses
# Han pasado 1 meses
# Han pasado 2 meses
# Han pasado 3 meses
# Han pasado 4 meses
# Han pasado 5 meses
# Han pasado 6 meses
# Han pasado 7 meses
# Han pasado 8 meses
# Han pasado 9 meses

# %%
string1 = "Pearl"
string2 = "Jam"
print(string1, string2)
# Out:
# Pearl Jam

# %%
string = "Dime tu edad :"
edad = input(string)
print("Tienes",edad,"años :D");
# Out:
# Dime tu edad :20
# Tienes 20 años :D

# %%
def funcion():
  return "Aquí se termina"
  print(5)

# %%
def calculo(numero):
  resultado = (numero -3) ** 3
  return resultado

print(calculo(8))
salida = calculo(5)
print(salida + 100)
# Out:
# 125
# 108

# %%
def es_par(numero):
  if numero % 2 == 0:
    return True
  else:
    return False
print(es_par(8))
print(es_par(7))
# Out:
# True
# False

# %%
import math
math.sin(0)
# Out:
# 0.0

# %%
from random import uniform
uniform(0,1)
# Out:
# 0.6601292054624028

# %%
from random import randint as rnd
rnd(5, 10)
# Out:
# 8

# %%
from random import randint as rnd
from math import pi, e

lanzamiento = rnd(1,6)
if lanzamiento < 4:
  print(pi * lanzamiento)
else:
  print (e * lanzamiento)
# Out:
# 6.283185307179586

# %%
x=1
i=0
while i<4:
  x=x*2
  i+=1
print(x)
# Out:
# 16

# %%
x = 48
y = 8
n = 0
while x>0:
  x=x-y
  n=n+1
print(x)
# Out:
# 0

# %%
a=3
for i in range(2,5):
  a=a*i
  print (a)
# Out:
# 6
# 18
# 72

# %%
#OBJETO que debe ir para imprimir 10 veces hola mundo
for i in range(1,11):
  print("hola mundo")
# Out:
# hola mundo
# hola mundo
# hola mundo
# hola mundo
# hola mundo
# hola mundo
# hola mundo
# hola mundo
# hola mundo
# hola mundo
